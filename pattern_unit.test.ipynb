# %%
import numpy as np

from src.geometry.pattern_unit import (
    PatternUnit,
    Shape,
    PatternTransformation,
    PatternTransformationVector,
    Pattern,
)
from src.grid.visualize_points import visualize_points


shape = Shape(
    w=10,
    h=5,
    area_functions=[
        # lambda x, y: x**2 + y**2 <= 25,  # circle
        lambda x, y: x**2 / 9 + y**2 / 4 <= 1,  # ellipse
        lambda x, y: abs(x / 2) + abs(y) <= 2,  # diamond
        # lambda x, y: y >= x**2 / 4 + 1,  # parabola
    ],
)

# create the pattern unit
pattern_unit = PatternUnit(shape, k=0.5)

visualize_points(pattern_unit.shape_points)

# %%
shape2 = Shape(
    w=10,
    h=10,
    area_functions=[
        lambda x, y: x**2 + y**2 <= 25 and x**2 + y**2 >= 9,  # Donut
    ],
)

# create the pattern unit
pattern_unit2 = PatternUnit(shape2, k=0.1)

visualize_points(pattern_unit2.shape_points)

# %%
circular_transformation = PatternTransformation(
    Dx=2.5,
    Od=25,
    Phi=np.pi / 8,
)
circular_transformation_vector = PatternTransformationVector(
    pattern_unit=pattern_unit2,
    pattern_transformation=circular_transformation,
    pattern_bound=((-100, 100), (-100, 100)),
)

# print(circular_transformation_vector.L)

circular_pattern = Pattern(
    pattern_unit=pattern_unit2,
    pattern_transformation_vector=circular_transformation_vector,
)

# print(circular_pattern.pattern_points)
# visualize_points(circular_pattern.pattern_points)
# Out:
# min_phi: 0.3760079133641484, Phi: 0.39269908169872414

# %%
corn_transformation = PatternTransformation(
    Dx=2.5,
    Od=16.5,
    Phi=np.pi / 10,
    Rotate_count=4,
)

corn_transformation_vector = PatternTransformationVector(
    pattern_unit=pattern_unit,
    pattern_transformation=corn_transformation,
    pattern_bound=((0, 100), (0, 100)),
)

print(corn_transformation_vector.L)

corn_pattern = Pattern(
    pattern_unit=pattern_unit,
    pattern_transformation_vector=corn_transformation_vector,
)


print(corn_pattern.pattern_points)
visualize_points(corn_pattern.pattern_points)
# Out:
# min_phi: 0.2921381743394878, Phi: 0.3141592653589793
# [array([21.5,  0. ,  0. ]), array([34.,  0.,  0.]), array([46.5,  0. ,  0. ]), array([59.,  0.,  0.]), array([71.5,  0. ,  0. ]), array([84.,  0.,  0.]), array([96.5,  0. ,  0. ]), array([20.4477151 ,  6.64386538,  0.31415927]), array([32.33592155, 10.50657781,  0.31415927]), array([44.22412801, 14.36929024,  0.31415927]), array([56.11233446, 18.23200267,  0.31415927]), array([68.00054092, 22.0947151 ,  0.31415927]), array([79.88874737, 25.95742753,  0.31415927]), array([91.77695382, 29.82013996,  0.31415927]), array([20.4477151 , -6.64386538, -0.31415927]), array([ 32.33592155, -10.50657781,  -0.31415927]), array([ 44.22412801, -14.36929024,  -0.31415927]), array([ 56.11233446, -18.23200267,  -0.31415927]), array([ 68.00054092, -22.0947151 ,  -0.31415927]), array([ 79.88874737, -25.95742753,  -0.31415927]), array([ 91.77695382, -29.82013996,  -0.31415927]), array([17.39386538, 12.63738292,  0.62831853]), array([27.50657781, 19.98469858,  0.62831853]), array([37.61929024, 27.33201423,  0.62831853]), array([47.73200267, 34.67932989,  0.62831853]), array([57.8447151 , 42.02664554,  0.62831853]), array([67.95742753, 49.37396119,  0.62831853]), array([78.07013996, 56.72127685,  0.62831853]), array([ 17.39386538, -12.63738292,  -0.62831853]), array([ 27.50657781, -19.98469858,  -0.62831853]), array([ 37.61929024, -27.33201423,  -0.62831853]), array([ 47.73200267, -34.67932989,  -0.62831853]), array([ 57.8447151 , -42.02664554,  -0.62831853]), array([ 67.95742753, -49.37396119,  -0.62831853]), array([ 78.07013996, -56.72127685,  -0.62831853])]
# [GridCell(k=0.5, coord=[18.5  0. ]), GridCell(k=0.5, coord=[19. -1.]), GridCell(k=0.5, coord=[19.  -0.5]), GridCell(k=0.5, coord=[19.  0.]), GridCell(k=0.5, coord=[19.   0.5]), GridCell(k=0.5, coord=[19.  1.]), GridCell(k=0.5, coord=[19.5 -1. ]), GridCell(k=0.5, coord=[19.5 -0.5]), GridCell(k=0.5, coord=[19.5  0. ]), GridCell(k=0.5, coord=[19.5  0.5]), GridCell(k=0.5, coord=[19.5  1. ]), GridCell(k=0.5, coord=[20.  -1.5]), GridCell(k=0.5, coord=[20. -1.]), GridCell(k=0.5, coord=[20.  -0.5]), GridCell(k=0.5, coord=[20.  0.]), GridCell(k=0.5, coord=[20.   0.5]), GridCell(k=0.5, coord=[20.  1.]), GridCell(k=0.5, coord=[20.   1.5]), GridCell(k=0.5, coord=[20.5 -1.5]), GridCell(k=0.5, coord=[20.5 -1. ]), GridCell(k=0.5, coord=[20.5 -0.5]), GridCell(k=0.5, coord=[20.5  0. ]), GridCell(k=0.5, coord=[20.5  0.5]), GridCell(k=0.5, coord=[20.5  1. ]), GridCell(k=0.5, coord=[20.5  1.5]), GridCell(k=0.5, coord=[21.  -1.5]), GridCell(k=0.5, coord=[21. -1.]), GridCell(k=0.5, coord=[21.  -0.5]), GridCell(k=0.5, coord=[21.  0.]), GridCell(k=0.5, coord=[21.   0.5]), GridCell(k=0.5, coord=[21.  1.]), GridCell(k=0.5, coord=[21.   1.5]), GridCell(k=0.5, coord=[21.5 -2. ]), GridCell(k=0.5, coord=[21.5 -1.5]), GridCell(k=0.5, coord=[21.5 -1. ]), GridCell(k=0.5, coord=[21.5 -0.5]), GridCell(k=0.5, coord=[21.5  0. ]), GridCell(k=0.5, coord=[21.5  0.5]), GridCell(k=0.5, coord=[21.5  1. ]), GridCell(k=0.5, coord=[21.5  1.5]), GridCell(k=0.5, coord=[21.5  2. ]), GridCell(k=0.5, coord=[22.  -1.5]), GridCell(k=0.5, coord=[22. -1.]), GridCell(k=0.5, coord=[22.  -0.5]), GridCell(k=0.5, coord=[22.  0.]), GridCell(k=0.5, coord=[22.   0.5]), GridCell(k=0.5, coord=[22.  1.]), GridCell(k=0.5, coord=[22.   1.5]), GridCell(k=0.5, coord=[22.5 -1.5]), GridCell(k=0.5, coord=[22.5 -1. ]), GridCell(k=0.5, coord=[22.5 -0.5]), GridCell(k=0.5, coord=[22.5  0. ]), GridCell(k=0.5, coord=[22.5  0.5]), GridCell(k=0.5, coord=[22.5  1. ]), GridCell(k=0.5, coord=[22.5  1.5]), GridCell(k=0.5, coord=[23.  -1.5]), GridCell(k=0.5, coord=[23. -1.]), GridCell(k=0.5, coord=[23.  -0.5]), GridCell(k=0.5, coord=[23.  0.]), GridCell(k=0.5, coord=[23.   0.5]), GridCell(k=0.5, coord=[23.  1.]), GridCell(k=0.5, coord=[23.   1.5]), GridCell(k=0.5, coord=[23.5 -1. ]), GridCell(k=0.5, coord=[23.5 -0.5]), GridCell(k=0.5, coord=[23.5  0. ]), GridCell(k=0.5, coord=[23.5  0.5]), GridCell(k=0.5, coord=[23.5  1. ]), GridCell(k=0.5, coord=[24. -1.]), GridCell(k=0.5, coord=[24.  -0.5]), GridCell(k=0.5, coord=[24.  0.]), GridCell(k=0.5, coord=[24.   0.5]), GridCell(k=0.5, coord=[24.  1.]), GridCell(k=0.5, coord=[24.5  0. ]), GridCell(k=0.5, coord=[17.5  0. ]), GridCell(k=0.5, coord=[18.  0.]), GridCell(k=0.5, coord=[18.5 -0.5]), GridCell(k=0.5, coord=[18.5  0.5]), GridCell(k=0.5, coord=[24.5 -0.5]), GridCell(k=0.5, coord=[24.5  0.5]), GridCell(k=0.5, coord=[25.  0.]), GridCell(k=0.5, coord=[25.5  0. ]), GridCell(k=0.5, coord=[31.  0.]), GridCell(k=0.5, coord=[31.5 -1. ]), GridCell(k=0.5, coord=[31.5 -0.5]), GridCell(k=0.5, coord=[31.5  0. ]), GridCell(k=0.5, coord=[31.5  0.5]), GridCell(k=0.5, coord=[31.5  1. ]), GridCell(k=0.5, coord=[32. -1.]), GridCell(k=0.5, coord=[32.  -0.5]), GridCell(k=0.5, coord=[32.  0.]), GridCell(k=0.5, coord=[32.   0.5]), GridCell(k=0.5, coord=[32.  1.]), GridCell(k=0.5, coord=[32.5 -1.5]), GridCell(k=0.5, coord=[32.5 -1. ]), GridCell(k=0.5, coord=[32.5 -0.5]), GridCell(k=0.5, coord=[32.5  0. ]), GridCell(k=0.5, coord=[32.5  0.5]), GridCell(k=0.5, coord=[32.5  1. ]), GridCell(k=0.5, coord=[32.5  1.5]), GridCell(k=0.5, coord=[33.  -1.5]), GridCell(k=0.5, coord=[33. -1.]), GridCell(k=0.5, coord=[33.  -0.5]), GridCell(k=0.5, coord=[33.  0.]), GridCell(k=0.5, coord=[33.   0.5]), GridCell(k=0.5, coord=[33.  1.]), GridCell(k=0.5, coord=[33.   1.5]), GridCell(k=0.5, coord=[33.5 -1.5]), GridCell(k=0.5, coord=[33.5 -1. ]), GridCell(k=0.5, coord=[33.5 -0.5]), GridCell(k=0.5, coord=[33.5  0. ]), GridCell(k=0.5, coord=[33.5  0.5]), GridCell(k=0.5, coord=[33.5  1. ]), GridCell(k=0.5, coord ...

# %%
Dx = 5
grid_transformation = PatternTransformation(Dx=Dx, Dy=2.5, Od=Dx / 2)

grid_transformation_vector = PatternTransformationVector(
    pattern_unit=pattern_unit,
    pattern_transformation=grid_transformation,
    pattern_bound=((-100, 100), (-100, 100)),
)

print(grid_transformation_vector.L)
grid_pattern = Pattern(
    pattern_unit=pattern_unit,
    pattern_transformation_vector=grid_transformation_vector,
)

grid_pattern.generate_pattern_points()

print(grid_pattern.pattern_points)
visualize_points(grid_pattern.pattern_points)
# Out:
# [array([7.5, 0. , 0. ]), array([22.5,  0. ,  0. ]), array([37.5,  0. ,  0. ]), array([52.5,  0. ,  0. ]), array([67.5,  0. ,  0. ]), array([82.5,  0. ,  0. ]), array([97.5,  0. ,  0. ]), array([-7.5,  0. ,  0. ]), array([-22.5,   0. ,   0. ]), array([-37.5,   0. ,   0. ]), array([-52.5,   0. ,   0. ]), array([-67.5,   0. ,   0. ]), array([-82.5,   0. ,   0. ]), array([-97.5,   0. ,   0. ]), array([7.5, 7.5, 0. ]), array([22.5,  7.5,  0. ]), array([37.5,  7.5,  0. ]), array([52.5,  7.5,  0. ]), array([67.5,  7.5,  0. ]), array([82.5,  7.5,  0. ]), array([97.5,  7.5,  0. ]), array([-7.5,  7.5,  0. ]), array([-22.5,   7.5,   0. ]), array([-37.5,   7.5,   0. ]), array([-52.5,   7.5,   0. ]), array([-67.5,   7.5,   0. ]), array([-82.5,   7.5,   0. ]), array([-97.5,   7.5,   0. ]), array([ 7.5, -7.5,  0. ]), array([22.5, -7.5,  0. ]), array([37.5, -7.5,  0. ]), array([52.5, -7.5,  0. ]), array([67.5, -7.5,  0. ]), array([82.5, -7.5,  0. ]), array([97.5, -7.5,  0. ]), array([-7.5, -7.5,  0. ]), array([-22.5,  -7.5,   0. ]), array([-37.5,  -7.5,   0. ]), array([-52.5,  -7.5,   0. ]), array([-67.5,  -7.5,   0. ]), array([-82.5,  -7.5,   0. ]), array([-97.5,  -7.5,   0. ]), array([ 7.5, 15. ,  0. ]), array([22.5, 15. ,  0. ]), array([37.5, 15. ,  0. ]), array([52.5, 15. ,  0. ]), array([67.5, 15. ,  0. ]), array([82.5, 15. ,  0. ]), array([97.5, 15. ,  0. ]), array([-7.5, 15. ,  0. ]), array([-22.5,  15. ,   0. ]), array([-37.5,  15. ,   0. ]), array([-52.5,  15. ,   0. ]), array([-67.5,  15. ,   0. ]), array([-82.5,  15. ,   0. ]), array([-97.5,  15. ,   0. ]), array([  7.5, -15. ,   0. ]), array([ 22.5, -15. ,   0. ]), array([ 37.5, -15. ,   0. ]), array([ 52.5, -15. ,   0. ]), array([ 67.5, -15. ,   0. ]), array([ 82.5, -15. ,   0. ]), array([ 97.5, -15. ,   0. ]), array([ -7.5, -15. ,   0. ]), array([-22.5, -15. ,   0. ]), array([-37.5, -15. ,   0. ]), array([-52.5, -15. ,   0. ]), array([-67.5, -15. ,   0. ]), array([-82.5, -15. ,   0. ]), array([-97.5, -15. ,   0. ]), array([ 7.5, 22.5,  0. ]), array([22.5, 22.5,  0. ]), array([37.5, 22.5,  0. ]), array([52.5, 22.5,  0. ]), array([67.5, 22.5,  0. ]), array([82.5, 22.5,  0. ]), array([97.5, 22.5,  0. ]), array([-7.5, 22.5,  0. ]), array([-22.5,  22.5,   0. ]), array([-37.5,  22.5,   0. ]), array([-52.5,  22.5,   0. ]), array([-67.5,  22.5,   0. ]), array([-82.5,  22.5,   0. ]), array([-97.5,  22.5,   0. ]), array([  7.5, -22.5,   0. ]), array([ 22.5, -22.5,   0. ]), array([ 37.5, -22.5,   0. ]), array([ 52.5, -22.5,   0. ]), array([ 67.5, -22.5,   0. ]), array([ 82.5, -22.5,   0. ]), array([ 97.5, -22.5,   0. ]), array([ -7.5, -22.5,   0. ]), array([-22.5, -22.5,   0. ]), array([-37.5, -22.5,   0. ]), array([-52.5, -22.5,   0. ]), array([-67.5, -22.5,   0. ]), array([-82.5, -22.5,   0. ]), array([-97.5, -22.5,   0. ]), array([ 7.5, 30. ,  0. ]), array([22.5, 30. ,  0. ]), array([37.5, 30. ,  0. ]), array([52.5, 30. ,  0. ]), array([67.5, 30. ,  0. ]), array([82.5, 30. ,  0. ]), array([97.5, 30. ,  0. ]), array([-7.5, 30. ,  0. ]), array([-22.5,  30. ,   0. ]), array([-37.5,  30. ,   0. ]), array([-52.5,  30. ,   0. ]), array([-67.5,  30. ,   0. ]), array([-82.5,  30. ,   0. ]), array([-97.5,  30. ,   0. ]), array([  7.5, -30. ,   0. ]), array([ 22.5, -30. ,   0. ]), array([ 37.5, -30. ,   0. ]), array([ 52.5, -30. ,   0. ]), array([ 67.5, -30. ,   0. ]), array([ 82.5, -30. ,   0. ]), array([ 97.5, -30. ,   0. ]), array([ -7.5, -30. ,   0. ]), array([-22.5, -30. ,   0. ]), array([-37.5, -30. ,   0. ]), array([-52.5, -30. ,   0. ]), array([-67.5, -30. ,   0. ]), array([-82.5, -30. ,   0. ]), array([-97.5, -30. ,   0. ]), array([ 7.5, 37.5,  0. ]), array([22.5, 37.5,  0. ]), array([37.5, 37.5,  0. ]), array([52.5, 37.5,  0. ]), array([67.5, 37.5,  0. ]), array([82.5, 37.5,  0. ]), array([97.5, 37.5,  0. ]), array([-7.5, 37.5,  0. ]), array([-22.5,  37.5,   0. ]), array([-37.5,  37.5,   0. ]), array([-52.5,  37.5,   0. ]), array([-67.5,  37.5,   0. ]), array([-82.5,  37.5,   0. ]), arr ...
# [GridCell(k=0.5, coord=[4.5 0. ]), GridCell(k=0.5, coord=[ 5. -1.]), GridCell(k=0.5, coord=[ 5.  -0.5]), GridCell(k=0.5, coord=[5. 0.]), GridCell(k=0.5, coord=[5.  0.5]), GridCell(k=0.5, coord=[5. 1.]), GridCell(k=0.5, coord=[ 5.5 -1. ]), GridCell(k=0.5, coord=[ 5.5 -0.5]), GridCell(k=0.5, coord=[5.5 0. ]), GridCell(k=0.5, coord=[5.5 0.5]), GridCell(k=0.5, coord=[5.5 1. ]), GridCell(k=0.5, coord=[ 6.  -1.5]), GridCell(k=0.5, coord=[ 6. -1.]), GridCell(k=0.5, coord=[ 6.  -0.5]), GridCell(k=0.5, coord=[6. 0.]), GridCell(k=0.5, coord=[6.  0.5]), GridCell(k=0.5, coord=[6. 1.]), GridCell(k=0.5, coord=[6.  1.5]), GridCell(k=0.5, coord=[ 6.5 -1.5]), GridCell(k=0.5, coord=[ 6.5 -1. ]), GridCell(k=0.5, coord=[ 6.5 -0.5]), GridCell(k=0.5, coord=[6.5 0. ]), GridCell(k=0.5, coord=[6.5 0.5]), GridCell(k=0.5, coord=[6.5 1. ]), GridCell(k=0.5, coord=[6.5 1.5]), GridCell(k=0.5, coord=[ 7.  -1.5]), GridCell(k=0.5, coord=[ 7. -1.]), GridCell(k=0.5, coord=[ 7.  -0.5]), GridCell(k=0.5, coord=[7. 0.]), GridCell(k=0.5, coord=[7.  0.5]), GridCell(k=0.5, coord=[7. 1.]), GridCell(k=0.5, coord=[7.  1.5]), GridCell(k=0.5, coord=[ 7.5 -2. ]), GridCell(k=0.5, coord=[ 7.5 -1.5]), GridCell(k=0.5, coord=[ 7.5 -1. ]), GridCell(k=0.5, coord=[ 7.5 -0.5]), GridCell(k=0.5, coord=[7.5 0. ]), GridCell(k=0.5, coord=[7.5 0.5]), GridCell(k=0.5, coord=[7.5 1. ]), GridCell(k=0.5, coord=[7.5 1.5]), GridCell(k=0.5, coord=[7.5 2. ]), GridCell(k=0.5, coord=[ 8.  -1.5]), GridCell(k=0.5, coord=[ 8. -1.]), GridCell(k=0.5, coord=[ 8.  -0.5]), GridCell(k=0.5, coord=[8. 0.]), GridCell(k=0.5, coord=[8.  0.5]), GridCell(k=0.5, coord=[8. 1.]), GridCell(k=0.5, coord=[8.  1.5]), GridCell(k=0.5, coord=[ 8.5 -1.5]), GridCell(k=0.5, coord=[ 8.5 -1. ]), GridCell(k=0.5, coord=[ 8.5 -0.5]), GridCell(k=0.5, coord=[8.5 0. ]), GridCell(k=0.5, coord=[8.5 0.5]), GridCell(k=0.5, coord=[8.5 1. ]), GridCell(k=0.5, coord=[8.5 1.5]), GridCell(k=0.5, coord=[ 9.  -1.5]), GridCell(k=0.5, coord=[ 9. -1.]), GridCell(k=0.5, coord=[ 9.  -0.5]), GridCell(k=0.5, coord=[9. 0.]), GridCell(k=0.5, coord=[9.  0.5]), GridCell(k=0.5, coord=[9. 1.]), GridCell(k=0.5, coord=[9.  1.5]), GridCell(k=0.5, coord=[ 9.5 -1. ]), GridCell(k=0.5, coord=[ 9.5 -0.5]), GridCell(k=0.5, coord=[9.5 0. ]), GridCell(k=0.5, coord=[9.5 0.5]), GridCell(k=0.5, coord=[9.5 1. ]), GridCell(k=0.5, coord=[10. -1.]), GridCell(k=0.5, coord=[10.  -0.5]), GridCell(k=0.5, coord=[10.  0.]), GridCell(k=0.5, coord=[10.   0.5]), GridCell(k=0.5, coord=[10.  1.]), GridCell(k=0.5, coord=[10.5  0. ]), GridCell(k=0.5, coord=[3.5 0. ]), GridCell(k=0.5, coord=[4. 0.]), GridCell(k=0.5, coord=[ 4.5 -0.5]), GridCell(k=0.5, coord=[4.5 0.5]), GridCell(k=0.5, coord=[10.5 -0.5]), GridCell(k=0.5, coord=[10.5  0.5]), GridCell(k=0.5, coord=[11.  0.]), GridCell(k=0.5, coord=[11.5  0. ]), GridCell(k=0.5, coord=[19.5  0. ]), GridCell(k=0.5, coord=[20. -1.]), GridCell(k=0.5, coord=[20.  -0.5]), GridCell(k=0.5, coord=[20.  0.]), GridCell(k=0.5, coord=[20.   0.5]), GridCell(k=0.5, coord=[20.  1.]), GridCell(k=0.5, coord=[20.5 -1. ]), GridCell(k=0.5, coord=[20.5 -0.5]), GridCell(k=0.5, coord=[20.5  0. ]), GridCell(k=0.5, coord=[20.5  0.5]), GridCell(k=0.5, coord=[20.5  1. ]), GridCell(k=0.5, coord=[21.  -1.5]), GridCell(k=0.5, coord=[21. -1.]), GridCell(k=0.5, coord=[21.  -0.5]), GridCell(k=0.5, coord=[21.  0.]), GridCell(k=0.5, coord=[21.   0.5]), GridCell(k=0.5, coord=[21.  1.]), GridCell(k=0.5, coord=[21.   1.5]), GridCell(k=0.5, coord=[21.5 -1.5]), GridCell(k=0.5, coord=[21.5 -1. ]), GridCell(k=0.5, coord=[21.5 -0.5]), GridCell(k=0.5, coord=[21.5  0. ]), GridCell(k=0.5, coord=[21.5  0.5]), GridCell(k=0.5, coord=[21.5  1. ]), GridCell(k=0.5, coord=[21.5  1.5]), GridCell(k=0.5, coord=[22.  -1.5]), GridCell(k=0.5, coord=[22. -1.]), GridCell(k=0.5, coord=[22.  -0.5]), GridCell(k=0.5, coord=[22.  0.]), GridCell(k=0.5, coord=[22.   0.5]), GridCell(k=0.5, coord=[22.  1.]), GridCell(k=0.5, coord=[22.   1.5]), GridCell(k=0.5, coord=[22.5 -2. ]), GridCell(k=0.5, coord=[22.5 -1.5]), G ...
