# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from grid import Grid
from visualize_points import visualize_points

bound = ((-50, 100), (-50, 100))

grid = Grid(k=2, bound=bound)
grid.generate_grid()

visualize_points(grid.grid_cells)

# %% [markdown]
# ## Random point discretization

# %%
def generate_random_coords(count: int):
    random_coords = []
    for _ in range(count):
        x = np.random.uniform(0, 100)
        y = np.random.uniform(0, 100)
        random_coords.append(np.array([x, y]))

    return random_coords

# %%
rand_coords = generate_random_coords(1000)

fit = grid.fit_to_grid(rand_coords)
visualize_points(fit)

# %%
#
