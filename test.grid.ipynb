# %%
import numpy as np

# %%
from src.grid.grid import Grid
from src.grid.visualize_points import visualize_points

bound = ((-50, 50), (-50, 50))

grid = Grid(k=5, bound=bound)
grid.generate_grid()

visualize_points(grid.grid_matrix, k=grid.k)
# Out:
# [-50. -50.]
# [-50. -45.]
# [-50. -40.]
# [-50. -35.]
# [-50. -30.]
# [-50. -25.]
# [-50. -20.]
# [-50. -15.]
# [-50. -10.]
# [-50.  -5.]
# [-50.   0.]
# [-50.   5.]
# [-50.  10.]
# [-50.  15.]
# [-50.  20.]
# [-50.  25.]
# [-50.  30.]
# [-50.  35.]
# [-50.  40.]
# [-50.  45.]
# [-45. -50.]
# [-45. -45.]
# [-45. -40.]
# [-45. -35.]
# [-45. -30.]
# [-45. -25.]
# [-45. -20.]
# [-45. -15.]
# [-45. -10.]
# [-45.  -5.]
# [-45.   0.]
# [-45.   5.]
# [-45.  10.]
# [-45.  15.]
# [-45.  20.]
# [-45.  25.]
# [-45.  30.]
# [-45.  35.]
# [-45.  40.]
# [-45.  45.]
# [-40. -50.]
# [-40. -45.]
# [-40. -40.]
# [-40. -35.]
# [-40. -30.]
# [-40. -25.]
# [-40. -20.]
# [-40. -15.]
# [-40. -10.]
# [-40.  -5.]
# [-40.   0.]
# [-40.   5.]
# [-40.  10.]
# [-40.  15.]
# [-40.  20.]
# [-40.  25.]
# [-40.  30.]
# [-40.  35.]
# [-40.  40.]
# [-40.  45.]
# [-35. -50.]
# [-35. -45.]
# [-35. -40.]
# [-35. -35.]
# [-35. -30.]
# [-35. -25.]
# [-35. -20.]
# [-35. -15.]
# [-35. -10.]
# [-35.  -5.]
# [-35.   0.]
# ...

# %% [markdown]
# ## Random point discretization

# %%
def generate_random_coords(count: int):
    random_coords = []
    for _ in range(count):
        x = np.random.uniform(0, 100)
        y = np.random.uniform(0, 100)
        random_coords.append(np.array([x, y]))

    return random_coords

# %%
rand_coords = generate_random_coords(500)

fit = grid.fit_to_grid(rand_coords)
visualize_points(fit, grid.k)
# Out:
# [ 5. 35.]
# [10. 35.]
# [ 0. 20.]
# [ 5. 20.]
# [35. 35.]
# [40. 35.]
# [45. 40.]
# [50. 40.]
# [90. 20.]
# [95. 20.]
# [ 5. 85.]
# [10. 85.]
# [ 0. 85.]
# [90. 85.]
# [95. 85.]
# [70. 35.]
# [75. 35.]
# [70. 70.]
# [75. 70.]
# [50.  0.]
# [55.  0.]
# [45.  5.]
# [50.  5.]
# [35.  0.]
# [40.  0.]
# [90.  0.]
# [95.  0.]
# [10. 55.]
# [15. 55.]
# [20. 50.]
# [25. 50.]
# [20. 25.]
# [25. 25.]
# [35. 90.]
# [40. 90.]
# [45. 25.]
# [50. 25.]
# [15. 80.]
# [20. 80.]
# [55. 15.]
# [60. 15.]
# [30. 30.]
# [35. 30.]
# [50. 85.]
# [55. 85.]
# [75. 10.]
# [80. 10.]
# [ 0. 35.]
# [85. 30.]
# [90. 30.]
# [40. 45.]
# [45. 45.]
# [10.  5.]
# [15.  5.]
# [50. 50.]
# [55. 50.]
# [25. 75.]
# [30. 75.]
# [75.  5.]
# [80.  5.]
# [15. 25.]
# [40. 85.]
# [45. 85.]
# [85. 65.]
# [90. 65.]
# [75. 55.]
# [80. 55.]
# [5. 0.]
# [10.  0.]
# [ 5. 15.]
# [10. 15.]
# [55.  5.]
# [80. 25.]
# [85. 25.]
# [10. 10.]
# [15. 10.]
# [30. 50.]
# [35. 50.]
# [85. 70.]
# [90. 70.]
# [65. 70.]
# [ 0. 95.]
# [ 5. 95.]
# ...
